# %%
import numpy as numpy
import pandas as pd 
import seaborn as sbrn 
import matplotlib.pyplot as plt

# %% [markdown]
# ##Reading Data

# %%
df = pd.read_csv("../3yearsuntouched.csv")

# %%
df
# Out:
#         Unnamed: 0  Year  Severity           Start_Time             End_Time  \
# 0                2  2016         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 1                3  2016         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 2                4  2016         2  2016-02-08 07:39:07  2016-02-08 08:09:07
# 3                5  2016         3  2016-02-08 07:44:26  2016-02-08 08:14:26
# 4                6  2016         2  2016-02-08 07:59:35  2016-02-08 08:29:35
# ...            ...   ...       ...                  ...                  ...
# 314280     7652504  2017         2  2017-08-29 14:32:25  2017-08-29 20:32:25
# 314281     7652579  2017         2  2017-08-29 15:15:51  2017-08-29 21:15:51
# 314282     7652658  2017         2  2017-08-29 15:55:36  2017-08-29 21:55:36
# 314283     7653119  2017         4  2017-08-30 05:08:21  2017-08-30 11:08:21
# 314284     7653237  2017         3  2017-08-30 08:51:10  2017-08-30 14:51:10
#
#         Start_Lat   Start_Lng  Distance(mi)                     Street  \
# 0       39.063148  -84.032608         0.010             State Route 32
# 1       39.747753  -84.205582         0.010                     I-75 S
# 2       39.627781  -84.188354         0.010  Miamisburg Centerville Rd
# 3       40.100590  -82.925194         0.010             Westerville Rd
# 4       39.758274  -84.230507         0.000             N Woodward Ave
# ...           ...         ...           ...                        ...
# 314280  28.879630  -82.092960         0.722                     I-75 S
# 314281  37.993881  -92.795869         0.000             Sunny Slope Dr
# 314282  46.617235 -113.051251         0.000                    US-12 W
# 314283  46.672100 -113.153690         9.486                    US-12 W
# 314284  34.344290 -118.504950         0.430                    CA-14 S
#
#                 City  ...     Zipcode     Timezone Airport_Code  \
# 0       Williamsburg  ...       45176   US/Eastern         KI69
# 1             Dayton  ...       45417   US/Eastern         KDAY
# 2             Dayton  ...       45459   US/Eastern         KMGY
# 3        Westerville  ...       43081   US/Eastern         KCMH
# 4             Dayton  ...  45417-2476   US/Eastern         KDAY
# ...              ...  ...         ...          ...          ...
# 314280      Wildwood  ...       34785   US/Eastern         KVVG
# 314281     Camdenton  ...       65020   US/Central         KH21
# 314282      Drummond  ...       59832  US/Mountain         K3DU
# 314283      Drummond  ...       59832  US/Mountain         K3DU
# 314284       Newhall  ...       91321   US/Pacific         K3A6
#
#        Temperature(F) Wind_Chill(F)  Visibility(mi)  Wind_Direction  \
# 0                36.0          33.3            10.0              SW
# 1                35.1          31.0             9.0              SW
# 2                36.0          33.3             6.0              SW
# 3                37.9          35.5             7.0             SSW
# 4                34.0          31.0             7.0             WSW
# ...               ...           ...             ...             ...
# 314280           80.0          80.0            10.0             VAR
# 314281           75.0          75.0            10.0               N
# 314282           89.0          89.0             3.0             SSE
# 314283           57.0          57.0             4.0            CALM
# 314284           85.0          85.0            10.0            CALM
#
#               Weather_Condition Traffic_Signal Sunrise_Sunset
# 0                      Overcast           True          Night
# 1                 Mostly Cloudy          False          Night
# 2                 Mostly Cloudy           True            Day
# 3                    Light Rain          False            Day
# 4                      Overcast          False            Day
# ...                         ...            ...            ...
# 314280  Light Rain with Thunder          False            Day
# 314281                   Cloudy          False            Day
# 314282                     Haze          False            Day
# 314283                     Haze          False          Night
# 314284                     Fair          False            Day
#
# [314285 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 314285 entries, 0 to 314284
# Data columns (total 22 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Unnamed: 0         314285 non-null  int64
#  1   Year               314285 non-null  int64
#  2   Severity           314285 non-null  int64
#  3   Start_Time         314285 non-null  object
#  4   End_Time           314285 non-null  object
#  5   Start_Lat          314285 non-null  float64
#  6   Start_Lng          314285 non-null  float64
#  7   Distance(mi)       314285 non-null  float64
#  8   Street             314285 non-null  object
#  9   City               314285 non-null  object
#  10  County             314285 non-null  object
#  11  State              314285 non-null  object
#  12  Zipcode            314285 non-null  object
#  13  Timezone           314285 non-null  object
#  14  Airport_Code       314285 non-null  object
#  15  Temperature(F)     314285 non-null  float64
#  16  Wind_Chill(F)      314285 non-null  float64
#  17  Visibility(mi)     314285 non-null  float64
#  18  Wind_Direction     314285 non-null  object
#  19  Weather_Condition  314285 non-null  object
#  20  Traffic_Signal     314285 non-null  bool
#  21  Sunrise_Sunset     314285 non-null  object
# dtypes: bool(1), float64(6), int64(3), object(12)
# memory usage: 50.7+ MB

# %%
df.iat[0,3]
# Out:
# '2016-02-08 06:49:27'

# %%
df.iat[0,4]
# Out:
# '2016-02-08 07:19:27'

# %%
for i in range(314284):
    if(len(df.iat[i,3])>19 or len(df.iat[i,4])>19):
        df.iat[i,3] = df.iat[i,3][:19]
        df.iat[i,4] = df.iat[i,4][:19]

# %%
Start_Time = pd.to_datetime(df.Start_Time)
End_Time = pd.to_datetime(df.End_Time)
Time_Diff = (End_Time - Start_Time).astype('timedelta64[s]')

# %%
Time_Diff
# Out:
# 0        0 days 00:30:00
# 1        0 days 00:30:00
# 2        0 days 00:30:00
# 3        0 days 00:30:00
# 4        0 days 00:30:00
#                ...
# 314280   0 days 06:00:00
# 314281   0 days 06:00:00
# 314282   0 days 06:00:00
# 314283   0 days 06:00:00
# 314284   0 days 06:00:00
# Length: 314285, dtype: timedelta64[s]

# %%
min(Time_Diff)
# Out:
# Timedelta('0 days 00:07:00')

# %%
max(End_Time)
# Out:
# Timestamp('2022-07-20 10:49:45')

# %%
min(Start_Time)
# Out:
# Timestamp('2016-01-14 20:18:33')

# %%
max(Time_Diff)
# Out:
# Timedelta('1553 days 01:25:45')

# %%
df['TimeDiff'] = Time_Diff

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 314285 entries, 0 to 314284
# Data columns (total 23 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Unnamed: 0         314285 non-null  int64
#  1   Year               314285 non-null  int64
#  2   Severity           314285 non-null  int64
#  3   Start_Time         314285 non-null  object
#  4   End_Time           314285 non-null  object
#  5   Start_Lat          314285 non-null  float64
#  6   Start_Lng          314285 non-null  float64
#  7   Distance(mi)       314285 non-null  float64
#  8   Street             314285 non-null  object
#  9   City               314285 non-null  object
#  10  County             314285 non-null  object
#  11  State              314285 non-null  object
#  12  Zipcode            314285 non-null  object
#  13  Timezone           314285 non-null  object
#  14  Airport_Code       314285 non-null  object
#  15  Temperature(F)     314285 non-null  float64
#  16  Wind_Chill(F)      314285 non-null  float64
#  17  Visibility(mi)     314285 non-null  float64
#  18  Wind_Direction     314285 non-null  object
#  19  Weather_Condition  314285 non-null  object
#  20  Traffic_Signal     314285 non-null  bool
#  21  Sunrise_Sunset     314285 non-null  object
#  22  TimeDiff           314285 non-null  timedelta64[s]
# dtypes: bool(1), float64(6), int64(3), object(12), timedelta64[s](1)
# memory usage: 53.1+ MB

# %%
new = df.drop(columns=['Start_Time','End_Time','Zipcode','Timezone'])

# %%
new
# Out:
#         Unnamed: 0  Year  Severity  Start_Lat   Start_Lng  Distance(mi)  \
# 0                2  2016         2  39.063148  -84.032608         0.010
# 1                3  2016         3  39.747753  -84.205582         0.010
# 2                4  2016         2  39.627781  -84.188354         0.010
# 3                5  2016         3  40.100590  -82.925194         0.010
# 4                6  2016         2  39.758274  -84.230507         0.000
# ...            ...   ...       ...        ...         ...           ...
# 314280     7652504  2017         2  28.879630  -82.092960         0.722
# 314281     7652579  2017         2  37.993881  -92.795869         0.000
# 314282     7652658  2017         2  46.617235 -113.051251         0.000
# 314283     7653119  2017         4  46.672100 -113.153690         9.486
# 314284     7653237  2017         3  34.344290 -118.504950         0.430
#
#                            Street          City       County State  \
# 0                  State Route 32  Williamsburg     Clermont    OH
# 1                          I-75 S        Dayton   Montgomery    OH
# 2       Miamisburg Centerville Rd        Dayton   Montgomery    OH
# 3                  Westerville Rd   Westerville     Franklin    OH
# 4                  N Woodward Ave        Dayton   Montgomery    OH
# ...                           ...           ...          ...   ...
# 314280                     I-75 S      Wildwood       Sumter    FL
# 314281             Sunny Slope Dr     Camdenton       Camden    MO
# 314282                    US-12 W      Drummond      Granite    MT
# 314283                    US-12 W      Drummond      Granite    MT
# 314284                    CA-14 S       Newhall  Los Angeles    CA
#
#        Airport_Code  Temperature(F)  Wind_Chill(F)  Visibility(mi)  \
# 0              KI69            36.0           33.3            10.0
# 1              KDAY            35.1           31.0             9.0
# 2              KMGY            36.0           33.3             6.0
# 3              KCMH            37.9           35.5             7.0
# 4              KDAY            34.0           31.0             7.0
# ...             ...             ...            ...             ...
# 314280         KVVG            80.0           80.0            10.0
# 314281         KH21            75.0           75.0            10.0
# 314282         K3DU            89.0           89.0             3.0
# 314283         K3DU            57.0           57.0             4.0
# 314284         K3A6            85.0           85.0            10.0
#
#        Wind_Direction        Weather_Condition  Traffic_Signal Sunrise_Sunset  \
# 0                  SW                 Overcast            True          Night
# 1                  SW            Mostly Cloudy           False          Night
# 2                  SW            Mostly Cloudy            True            Day
# 3                 SSW               Light Rain           False            Day
# 4                 WSW                 Overcast           False            Day
# ...               ...                      ...             ...            ...
# 314280            VAR  Light Rain with Thunder           False            Day
# 314281              N                   Cloudy           False            Day
# 314282            SSE                     Haze           False            Day
# 314283           CALM                     Haze           False          Night
# 314284           CALM                     Fair           False            Day
#
#               TimeDiff
# 0      0 days 00:30:00
# 1      0 days 00:30:00
# 2      0 days 00:30:00
# 3      0 days 00:30:00
# 4      0 days 00:30:00
# ...                ...
# 314280 0 days 06:00:00
# 314281 0 days 06:00:00
# 314282 0 days 06:00:00
# 314283 0 days 06:00:00
# 314284 0 days 06:00:00
#
# [314285 rows x 19 columns]

# %%
# new = pd.read_csv("../Data/Cleandata.csv")

# %%
new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 314285 entries, 0 to 314284
# Data columns (total 19 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Unnamed: 0         314285 non-null  int64
#  1   Year               314285 non-null  int64
#  2   Severity           314285 non-null  int64
#  3   Start_Lat          314285 non-null  float64
#  4   Start_Lng          314285 non-null  float64
#  5   Distance(mi)       314285 non-null  float64
#  6   Street             314285 non-null  object
#  7   City               314285 non-null  object
#  8   County             314285 non-null  object
#  9   State              314285 non-null  object
#  10  Airport_Code       314285 non-null  object
#  11  Temperature(F)     314285 non-null  float64
#  12  Wind_Chill(F)      314285 non-null  float64
#  13  Visibility(mi)     314285 non-null  float64
#  14  Wind_Direction     314285 non-null  object
#  15  Weather_Condition  314285 non-null  object
#  16  Traffic_Signal     314285 non-null  bool
#  17  Sunrise_Sunset     314285 non-null  object
#  18  TimeDiff           314285 non-null  timedelta64[s]
# dtypes: bool(1), float64(6), int64(3), object(8), timedelta64[s](1)
# memory usage: 43.5+ MB

# %% [markdown]
# Duplicate Data Check and Removal

# %%
duplicate = new.duplicated().sum()
print('There are {} duplicated rows in the dataframe currently'.format(duplicate))
new.drop_duplicates(inplace=True)
new.reset_index(inplace=True, drop=True)
duplicate = new.duplicated().sum()
print('There are {} duplicated rows in the dataframe after duplicate removal'.format(duplicate))
new
# Out:
# There are 0 duplicated rows in the dataframe currently
# There are 0 duplicated rows in the dataframe after duplicate removal
#         Unnamed: 0  Year  Severity  Start_Lat   Start_Lng  Distance(mi)  \
# 0                2  2016         2  39.063148  -84.032608         0.010
# 1                3  2016         3  39.747753  -84.205582         0.010
# 2                4  2016         2  39.627781  -84.188354         0.010
# 3                5  2016         3  40.100590  -82.925194         0.010
# 4                6  2016         2  39.758274  -84.230507         0.000
# ...            ...   ...       ...        ...         ...           ...
# 314280     7652504  2017         2  28.879630  -82.092960         0.722
# 314281     7652579  2017         2  37.993881  -92.795869         0.000
# 314282     7652658  2017         2  46.617235 -113.051251         0.000
# 314283     7653119  2017         4  46.672100 -113.153690         9.486
# 314284     7653237  2017         3  34.344290 -118.504950         0.430
#
#                            Street          City       County State  \
# 0                  State Route 32  Williamsburg     Clermont    OH
# 1                          I-75 S        Dayton   Montgomery    OH
# 2       Miamisburg Centerville Rd        Dayton   Montgomery    OH
# 3                  Westerville Rd   Westerville     Franklin    OH
# 4                  N Woodward Ave        Dayton   Montgomery    OH
# ...                           ...           ...          ...   ...
# 314280                     I-75 S      Wildwood       Sumter    FL
# 314281             Sunny Slope Dr     Camdenton       Camden    MO
# 314282                    US-12 W      Drummond      Granite    MT
# 314283                    US-12 W      Drummond      Granite    MT
# 314284                    CA-14 S       Newhall  Los Angeles    CA
#
#        Airport_Code  Temperature(F)  Wind_Chill(F)  Visibility(mi)  \
# 0              KI69            36.0           33.3            10.0
# 1              KDAY            35.1           31.0             9.0
# 2              KMGY            36.0           33.3             6.0
# 3              KCMH            37.9           35.5             7.0
# 4              KDAY            34.0           31.0             7.0
# ...             ...             ...            ...             ...
# 314280         KVVG            80.0           80.0            10.0
# 314281         KH21            75.0           75.0            10.0
# 314282         K3DU            89.0           89.0             3.0
# 314283         K3DU            57.0           57.0             4.0
# 314284         K3A6            85.0           85.0            10.0
#
#        Wind_Direction        Weather_Condition  Traffic_Signal Sunrise_Sunset  \
# 0                  SW                 Overcast            True          Night
# 1                  SW            Mostly Cloudy           False          Night
# 2                  SW            Mostly Cloudy            True            Day
# 3                 SSW               Light Rain           False            Day
# 4                 WSW                 Overcast           False            Day
# ...               ...                      ...             ...            ...
# 314280            VAR  Light Rain with Thunder           False            Day
# 314281              N                   Cloudy           False            Day
# 314282            SSE                     Haze           False            Day
# 314283           CALM                     Haze           False          Night
# 314284           CALM                     Fair           False            Day
#
#               TimeDiff
# 0      0 days 00:30:00
# 1      0 days 00:30:00
# 2      0 days 00:30:00
# 3      0 days 00:30:00
# 4      0 days 00:30:00
# ...                ...
# 314280 0 days 06:00:00
# 314281 0 days 06:00:00
# 314282 0 days 06:00:00
# 314283 0 days 06:00:00
# 314284 0 days 06:00:00
#
# [314285 rows x 19 columns]

# %% [markdown]
# Null Data Check and Removal

# %%
new.isnull().sum()
# Out:
# Unnamed: 0           0
# Year                 0
# Severity             0
# Start_Lat            0
# Start_Lng            0
# Distance(mi)         0
# Street               0
# City                 0
# County               0
# State                0
# Airport_Code         0
# Temperature(F)       0
# Wind_Chill(F)        0
# Visibility(mi)       0
# Wind_Direction       0
# Weather_Condition    0
# Traffic_Signal       0
# Sunrise_Sunset       0
# TimeDiff             0
# dtype: int64

# %%
new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 314285 entries, 0 to 314284
# Data columns (total 19 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Unnamed: 0         314285 non-null  int64
#  1   Year               314285 non-null  int64
#  2   Severity           314285 non-null  int64
#  3   Start_Lat          314285 non-null  float64
#  4   Start_Lng          314285 non-null  float64
#  5   Distance(mi)       314285 non-null  float64
#  6   Street             314285 non-null  object
#  7   City               314285 non-null  object
#  8   County             314285 non-null  object
#  9   State              314285 non-null  object
#  10  Airport_Code       314285 non-null  object
#  11  Temperature(F)     314285 non-null  float64
#  12  Wind_Chill(F)      314285 non-null  float64
#  13  Visibility(mi)     314285 non-null  float64
#  14  Wind_Direction     314285 non-null  object
#  15  Weather_Condition  314285 non-null  object
#  16  Traffic_Signal     314285 non-null  bool
#  17  Sunrise_Sunset     314285 non-null  object
#  18  TimeDiff           314285 non-null  timedelta64[s]
# dtypes: bool(1), float64(6), int64(3), object(8), timedelta64[s](1)
# memory usage: 43.5+ MB

# %%
new['TimeDiff']=new['TimeDiff'].astype(int)/60
new['TimeDiff']
# Out:
# 0          30.0
# 1          30.0
# 2          30.0
# 3          30.0
# 4          30.0
#           ...
# 314280    360.0
# 314281    360.0
# 314282    360.0
# 314283    360.0
# 314284    360.0
# Name: TimeDiff, Length: 314285, dtype: float64

# %%
new
# Out:
#         Unnamed: 0  Year  Severity  Start_Lat   Start_Lng  Distance(mi)  \
# 0                2  2016         2  39.063148  -84.032608         0.010
# 1                3  2016         3  39.747753  -84.205582         0.010
# 2                4  2016         2  39.627781  -84.188354         0.010
# 3                5  2016         3  40.100590  -82.925194         0.010
# 4                6  2016         2  39.758274  -84.230507         0.000
# ...            ...   ...       ...        ...         ...           ...
# 314280     7652504  2017         2  28.879630  -82.092960         0.722
# 314281     7652579  2017         2  37.993881  -92.795869         0.000
# 314282     7652658  2017         2  46.617235 -113.051251         0.000
# 314283     7653119  2017         4  46.672100 -113.153690         9.486
# 314284     7653237  2017         3  34.344290 -118.504950         0.430
#
#                            Street          City       County State  \
# 0                  State Route 32  Williamsburg     Clermont    OH
# 1                          I-75 S        Dayton   Montgomery    OH
# 2       Miamisburg Centerville Rd        Dayton   Montgomery    OH
# 3                  Westerville Rd   Westerville     Franklin    OH
# 4                  N Woodward Ave        Dayton   Montgomery    OH
# ...                           ...           ...          ...   ...
# 314280                     I-75 S      Wildwood       Sumter    FL
# 314281             Sunny Slope Dr     Camdenton       Camden    MO
# 314282                    US-12 W      Drummond      Granite    MT
# 314283                    US-12 W      Drummond      Granite    MT
# 314284                    CA-14 S       Newhall  Los Angeles    CA
#
#        Airport_Code  Temperature(F)  Wind_Chill(F)  Visibility(mi)  \
# 0              KI69            36.0           33.3            10.0
# 1              KDAY            35.1           31.0             9.0
# 2              KMGY            36.0           33.3             6.0
# 3              KCMH            37.9           35.5             7.0
# 4              KDAY            34.0           31.0             7.0
# ...             ...             ...            ...             ...
# 314280         KVVG            80.0           80.0            10.0
# 314281         KH21            75.0           75.0            10.0
# 314282         K3DU            89.0           89.0             3.0
# 314283         K3DU            57.0           57.0             4.0
# 314284         K3A6            85.0           85.0            10.0
#
#        Wind_Direction        Weather_Condition  Traffic_Signal Sunrise_Sunset  \
# 0                  SW                 Overcast            True          Night
# 1                  SW            Mostly Cloudy           False          Night
# 2                  SW            Mostly Cloudy            True            Day
# 3                 SSW               Light Rain           False            Day
# 4                 WSW                 Overcast           False            Day
# ...               ...                      ...             ...            ...
# 314280            VAR  Light Rain with Thunder           False            Day
# 314281              N                   Cloudy           False            Day
# 314282            SSE                     Haze           False            Day
# 314283           CALM                     Haze           False          Night
# 314284           CALM                     Fair           False            Day
#
#         TimeDiff
# 0           30.0
# 1           30.0
# 2           30.0
# 3           30.0
# 4           30.0
# ...          ...
# 314280     360.0
# 314281     360.0
# 314282     360.0
# 314283     360.0
# 314284     360.0
#
# [314285 rows x 19 columns]

# %%
max(new['TimeDiff'])
# Out:
# 2236405.75

# %%
new['TimeDiff']
# Out:
# 0          30.0
# 1          30.0
# 2          30.0
# 3          30.0
# 4          30.0
#           ...
# 314280    360.0
# 314281    360.0
# 314282    360.0
# 314283    360.0
# 314284    360.0
# Name: TimeDiff, Length: 314285, dtype: float64

# %%
new=new.drop(columns=['Unnamed: 0'])

# %%
plt.figure(figsize=(10,5))
sbrn.pairplot(new,kind="reg")
plt.show()
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
new.to_csv("../Data/Cleandata.csv")

# %%
new

# %%
Withouttd = new.drop(columns=['TimeDiff'])

# %%
plt.figure(figsize=(10,5))
sbrn.pairplot(Withouttd,kind="reg")
plt.show()

# %%
fig, ax = plt.subplots(figsize = (10,5))
c = sbrn.countplot(x="Year", data=new, orient = 'v', palette = "crest")
# plt.annotate('Data Not Available',xy=(-0.4,500000), fontsize=11)
c.set_title("No. of Accidents in Year")
for i in ax.patches:
    count = '{:,.0f}'.format(i.get_height())
    x = i.get_x()+i.get_width()-0.60
    y = i.get_height()+1000
    ax.annotate(count, (x, y))
plt.show()

# %%
plt.figure
sbrn.pairplot(new,kind="scatter")            #scatter plots between all 9 numerical columns
plt.show()

# %%
# Importing
# Create the dataframe
column_name = new.feature_names
df_new = pd.DataFrame(new.data)
df_new .columns = column_name
df_new .head()
print("Old Shape: ", new.shape)

''' Detection '''
# IQR
# Calculate the upper and lower limits
Q1 = df_new['Start_Lat'].quantile(0.25)
Q3 = df_new['Start_Lat'].quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5*IQR
upper = Q3 + 1.5*IQR

# Create arrays of Boolean values indicating the outlier rows
upper_array = numpy.where(df_new['Start_Lat']>=upper)[0]
lower_array = numpy.where(df_new['Start_Lat']<=lower)[0]

print(upper_array)
print(lower_array)
# Removing the outliers
# new.drop(index=upper_array, inplace=True)
# new.drop(index=lower_array, inplace=True)

# Print the new shape of the DataFrame
print("New Shape: ", new.shape)
